# %% [markdown]
# # Time series clustering exercise

# %%
import os
import ast
import urllib2
import urllib
import pandas as pd
import json
from cStringIO import StringIO
import scipy.stats
from scipy.cluster.vq import whiten
from matplotlib import gridspec
from sklearn.cluster import KMeans
from pandas.tools.plotting import scatter_matrix
import geopandas as gp
import glob
from fiona.crs import from_epsg
import datetime as dt
import zipfile
from matplotlib import cm
from descartes import PolygonPatch
import scipy.cluster as scp
import pylab as pl
from pandas.io.common import ZipFile
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from geopandas import GeoDataFrame
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
PUIdata = os.getenv('PUIDATA')
print (PUIdata)
# Out:
# /home/cusp/rxl204/PUIdata

# %% [markdown]
# ### Download the census bureau business data for all years 1993-2014

# %%
# https://www2.census.gov
# ftp://ftp.census.gov

# !for ((y=93; y<=99; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done

# !for ((y=0; y<=1; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=2; y<=9; y+=1)); do wget \
https://www2.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=10; y<=14; y+=1)); do wget \
https://www2.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2017-12-12 12:26:34--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2017-12-12 12:26:35 ERROR 404: Not Found.
#
# --2017-12-12 12:26:35--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 611524 (597K) [application/zip]
# Saving to: “zbp94totals.zip”
#
# 100%[======================================>] 611,524     2.99M/s   in 0.2s
#
# 2017-12-12 12:26:35 (2.99 MB/s) - “zbp94totals.zip” saved [611524/611524]
#
# --2017-12-12 12:26:35--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625328 (611K) [application/zip]
# Saving to: “zbp95totals.zip”
#
# 100%[======================================>] 625,328     --.-K/s   in 0.03s
#
# 2017-12-12 12:26:35 (23.8 MB/s) - “zbp95totals.zip” saved [625328/625328]
#
# --2017-12-12 12:26:35--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632625 (618K) [application/zip]
# Saving to: “zbp96totals.zip”
#
# 100%[======================================>] 632,625     --.-K/s   in 0.07s
#
# 2017-12-12 12:26:35 (8.45 MB/s) - “zbp96totals.zip” saved [632625/632625]
#
# --2017-12-12 12:26:35--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629368 (615K) [application/zip]
# Saving to: “zbp97totals.zip”
#
# 100%[======================================>] 629,368     --.-K/s   in 0.04s
#
# 2017-12-12 12:26:36 (15.5 MB/s) - “zbp97totals.zip” saved [629368/629368]
#
# --2017-12-12 12:26:36--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp98totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617784 (603K) [application/zip]
# Saving to: “zbp98totals.zip”
#
# 100%[======================================>] 617,784     2.16M/s   in 0.3s
#
# 2017-12-12 12:26:36 (2.16 MB/s) - “zbp98totals.zip” saved [617784/617784]
#
# --2017-12-12 12:26:36--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625814 (611K) [application/zip]
# Saving to: “zbp99totals.zip”
#
# 100%[======================================>] 625,814     --.-K/s   in 0.07s
#
# 2017-12-12 12:26:37 (8.44 MB/s) - “zbp99totals.zip” saved [625814/625814]
#
# --2017-12-12 12:26:37--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628434 (614K) [application/zip]
# Saving to: “zbp00totals.zip”
#
# 100%[======================================>] 628,434     --.-K/s   in 0.05s
#
# 2017-12-12 12:26:37 (11.1 MB/s) - “zbp00totals.zip” saved [628434/628434]
#
# --2017-12-12 12:26:37--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628815 (614K) [application/zip]
# Saving to: “zbp01totals.zip”
#
# 100%[======================================>] 628,815     2.84M/s   in 0.2s
#
# 2017-12-12 12:26:37 (2.84 MB/s) - “zbp01totals.zip” saved [628815/628815]
#
# --2017-12-12 12:26:37--  https://www2.census.gov/econ2002/CBP_CSV/zbp02totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620754 (606K) [application/zip]
# Saving to: “zbp02totals.zip”
#
# 100%[======================================>] 620,754     1.12M/s   in 0.5s
#
# 2017-12-12 12:26:38 (1.12 MB/s) - “zbp02totals.zip” saved [620754/620754]
#
# --2017-12-12 12:26:38--  https://www2.census.gov/econ2003/CBP_CSV/zbp03totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622790 (608K) [application/zip]
# Saving to: “zbp03totals.zip”
#
# 100%[======================================>] 622,790     --.-K/s   in 0.07s
#
# 2017-12-12 12:26:38 (8.07 MB/s) - “zbp03totals.zip” saved [622790/622790]
#
# --2017-12-12 12:26:38--  https://www2.census.gov/econ2004/CBP_CSV/zbp04totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625803 (611K) [application/zip]
# Saving to: “zbp04totals.zip”
#
# 100%[======================================>] 625,803     --.-K/s   in 0.05s
#
# 2017-12-12 12:26:38 (13.1 MB/s) - “zbp04totals.zip” saved [625803/625803]
#
# --2017-12-12 12:26:38--  https://www2.census.gov/econ2005/CBP_CSV/zbp05totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627583 (613K) [application/zip]
# Saving to: “zbp05totals.zip”
#
# 100%[======================================>] 627,583      995K/s   in 0.6s
#
# 2017-12-12 12:26:39 (995 KB/s) - “zbp05totals.zip” saved [627583/627583]
#
# --2017-12-12 12:26:39--  https://www2.census.gov/econ2006/CBP_CSV/zbp06totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629107 (614K) [application/zip]
# Saving to: “zbp06totals.zip”
#
# 100%[======================================>] 629,107     2.82M/s   in 0.2s
#
# 2017-12-12 12:26:39 (2.82 MB/s) - “zbp06totals.zip” saved [629107/629107]
#
# --2017-12-12 12:26:39--  https://www2.census.gov/econ2007/CBP_CSV/zbp07totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667754 (652K) [application/zip]
# Saving to: “zbp07totals.zip”
#
# 100%[======================================>] 667,754     --.-K/s   in 0.1s
#
# 2017-12-12 12:26:39 (6.11 MB/s) - “zbp07totals.zip” saved [667754/667754]
#
# --2017-12-12 12:26:39--  https://www2.census.gov/econ2008/CBP_CSV/zbp08totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663242 (648K) [application/zip]
# Saving to: “zbp08totals.zip”
#
# 100%[======================================>] 663,242     --.-K/s   in 0.09s
#
# 2017-12-12 12:26:40 (7.40 MB/s) - “zbp08totals.zip” saved [663242/663242]
#
# --2017-12-12 12:26:40--  https://www2.census.gov/econ2009/CBP_CSV/zbp09totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 660109 (645K) [application/zip]
# Saving to: “zbp09totals.zip”
#
# 100%[======================================>] 660,109     --.-K/s   in 0.1s
#
# 2017-12-12 12:26:40 (4.84 MB/s) - “zbp09totals.zip” saved [660109/660109]
#
# --2017-12-12 12:26:40--  https://www2.census.gov/econ2010/CBP_CSV/zbp10totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797534 (779K) [application/zip]
# Saving to: “zbp10totals.zip”
#
# 100%[======================================>] 797,534     --.-K/s   in 0.1s
#
# 2017-12-12 12:26:40 (6.48 MB/s) - “zbp10totals.zip” saved [797534/797534]
#
# --2017-12-12 12:26:40--  https://www2.census.gov/econ2011/CBP_CSV/zbp11totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795390 (777K) [application/zip]
# Saving to: “zbp11totals.zip”
#
# 100%[======================================>] 795,390     --.-K/s   in 0.05s
#
# 2017-12-12 12:26:40 (14.0 MB/s) - “zbp11totals.zip” saved [795390/795390]
#
# --2017-12-12 12:26:40--  https://www2.census.gov/econ2012/CBP_CSV/zbp12totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733541 (716K) [application/zip]
# Saving to: “zbp12totals.zip”
#
# 100%[======================================>] 733,541     --.-K/s   in 0.06s
#
# 2017-12-12 12:26:40 (12.5 MB/s) - “zbp12totals.zip” saved [733541/733541]
#
# --2017-12-12 12:26:40--  https://www2.census.gov/econ2013/CBP_CSV/zbp13totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733605 (716K) [application/zip]
# Saving to: “zbp13totals.zip”
#
# 100%[======================================>] 733,605     --.-K/s   in 0.09s
#
# 2017-12-12 12:26:41 (7.74 MB/s) - “zbp13totals.zip” saved [733605/733605]
#
# --2017-12-12 12:26:41--  https://www2.census.gov/econ2014/CBP_CSV/zbp14totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733763 (717K) [application/zip]
# Saving to: “zbp14totals.zip”
#
# 100%[======================================>] 733,763     --.-K/s   in 0.09s
#
# 2017-12-12 12:26:41 (7.60 MB/s) - “zbp14totals.zip” saved [733763/733763]

# %% [markdown]
# ## Get Shapefile

# %%
# Get Zipcode files
# !wget https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# !unzip application%2Fzip
os.system("mv " + "ZIP* "+ os.getenv("PUIDATA"))
# Out:
# --2017-12-12 12:26:41--  https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# Resolving data.cityofnewyork.us... 52.206.68.26
# Connecting to data.cityofnewyork.us|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip [following]
# --2017-12-12 12:26:41--  https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip
# Connecting to data.cityofnewyork.us|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1514401 (1.4M) [application/octet-stream]
# Saving to: “application%2Fzip.4”
#
# 100%[======================================>] 1,514,401   1.97M/s   in 0.7s
#
# 2017-12-12 12:26:42 (1.97 MB/s) - “application%2Fzip.4” saved [1514401/1514401]
#
# Archive:  application%2Fzip
#   inflating: ZIP_CODE_040114.shx
#   inflating: ZIP_CODE_040114.dbf
#   inflating: ZIP_CODE_040114.prj
#   inflating: ZIP_CODE_040114.sbn
#   inflating: ZIP_CODE_040114.sbx
#   inflating: ZIP_CODE_040114.shp
#   inflating: ZIP_CODE_040114.shp.xml
# 0

# %%
dfzip = gp.read_file(PUIdata + "/ZIP_CODE_040114.shp")
dfzip.head()
# Out:
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  POLYGON ((1001613.712964058 186926.4395172149,...
# 2  POLYGON ((1011174.275535807 183696.33770971, 1...
# 3  POLYGON ((995908.3654508889 183617.6128015518,...
# 4  POLYGON ((991997.1134308875 176307.4958601296,...

# %%
dfzip['ZIPCODE'] = dfzip['ZIPCODE'].astype(int)

# %%
#move files to PUIdata
years = ['93', '94', '95', '96','97', '98','99', '00','01', '02', '03','04','05', '06', '07', '08','09', '10', '11', '12', '13', '14']
for i in years:
    os.system('mv zbp' + i + 'totals.zip $PUIDATA')

# %% [markdown]
# ## Data Cleaning

# %%
#merge data for all years into one dataframe
#checked in PUIdata - data only starts fro 1994. Financial Year possibly?
years = ['94', '95', '96','97', '98','99', '00','01', '02', '03','04','05', '06', '07', '08','09', '10', '11', '12', '13', '14']
appended_data = []
for i in years:
    zf = zipfile.ZipFile(PUIdata + "/" 
                         + "zbp" + i + "totals.zip")
    data = pd.read_csv(zf.open('zbp'+ i 
                               +'totals.zip'.replace('.zip','.txt')))
    data.columns = map(str.lower, data.columns)
    data['zip'] = data['zip'].astype(int)
    data = data.merge(dfzip, left_on='zip', right_on='ZIPCODE',how='inner')
    #store DataFrame in list
    appended_data.append(data)
appended_data = pd.concat(appended_data, axis=1)

# %%
appended_data
# Out:
#          zip              name empflag       emp        qp1         ap  \
# 0    10001.0      New York, NY     NaN  106160.0   781628.0  3375875.0
# 1    10002.0      New York, NY     NaN   13500.0    60207.0   258318.0
# 2    10003.0      New York, NY     NaN   59001.0   497286.0  2194890.0
# 3    10004.0      New York, NY     NaN   39428.0   685819.0  2615639.0
# 4    10004.0      New York, NY     NaN   39428.0   685819.0  2615639.0
# 5    10004.0      New York, NY     NaN   39428.0   685819.0  2615639.0
# 6    10004.0      New York, NY     NaN   39428.0   685819.0  2615639.0
# 7    10005.0      New York, NY     NaN   43540.0   807612.0  2937365.0
# 8    10006.0      New York, NY     NaN   28560.0   447201.0  1995852.0
# 9    10007.0      New York, NY     NaN   25427.0   247067.0  1023573.0
# 10   10009.0      New York, NY     NaN    5677.0    30985.0   139683.0
# 11   10010.0      New York, NY     NaN   67192.0   573526.0  2278418.0
# 12   10011.0      New York, NY     NaN   54495.0   384312.0  1689312.0
# 13   10012.0      New York, NY     NaN   33426.0   186604.0   859784.0
# 14   10013.0      New York, NY     NaN   61271.0   589206.0  1913846.0
# 15   10014.0      New York, NY     NaN   31598.0   243873.0  1034539.0
# 16   10016.0      New York, NY     NaN   95124.0   887476.0  3792733.0
# 17   10017.0      New York, NY     NaN  135846.0  1723647.0  7016396.0
# 18   10018.0      New York, NY     NaN   86116.0   804044.0  3417763.0
# 19   10019.0      New York, NY     NaN  122464.0  1646071.0  6387619.0
# 20   10020.0      New York, NY     NaN   34219.0   814616.0  2503929.0
# 21   10021.0      New York, NY     NaN   70267.0   606959.0  2638495.0
# 22   10022.0      New York, NY     NaN  124725.0  1929852.0  7532632.0
# 23   10023.0      New York, NY     NaN   34372.0   327513.0  1319604.0
# 24   10024.0      New York, NY     NaN   14695.0    72870.0   340670.0
# 25   10025.0      New York, NY     NaN   33381.0   244289.0   996890.0
# 26   10026.0      New York, NY     NaN     668.0     2767.0    11986.0
# 27   10027.0      New York, NY     NaN   12321.0    59275.0   247608.0
# 28   10028.0      New York, NY     NaN   14490.0    94453.0   420356.0
# 29   10029.0      New York, NY     NaN   21777.0   208772.0   869374.0
# ..       ...               ...     ...       ...        ...        ...
# 226  11414.0       Jamaica, NY     NaN    2644.0     9743.0    42460.0
# 227  11415.0       Jamaica, NY     NaN    3189.0    17318.0    71040.0
# 228  11416.0       Jamaica, NY     NaN    3609.0    19168.0    84071.0
# 229  11417.0       Jamaica, NY     NaN    4052.0    21846.0    97878.0
# 230  11418.0       Jamaica, NY     NaN    7827.0    47467.0   217575.0
# 231  11419.0       Jamaica, NY     NaN    2107.0     9348.0    42806.0
# 232  11420.0       Jamaica, NY     NaN    1372.0     6244.0    28737.0
# 233  11421.0       Jamaica, NY     NaN    1928.0     9048.0    40197.0
# 234  11422.0       Jamaica, NY     NaN    2295.0    13236.0    58144.0
# 235  11423.0       Jamaica, NY     NaN    2086.0    13118.0    57999.0
# 236  11426.0       Jamaica, NY     NaN    4249.0    20511.0    84978.0
# 237  11427.0       Jamaica, NY     NaN    3449.0    22804.0    92076.0
# 238  11428.0       Jamaica, NY     NaN    1119.0     6194.0    27213.0
# 239  11429.0       Jamaica, NY     NaN    1401.0     6766.0    30143.0
# 240  11430.0       Jamaica, NY     NaN   31366.0   233167.0   974324.0
# 241  11432.0       Jamaica, NY     NaN   18736.0   118024.0   503554.0
# 242  11433.0       Jamaica, NY     NaN    3512.0    21366.0    91388.0
# 243  11434.0       Jamaica, NY     NaN   10189.0    67086.0   283662.0
# 244  11435.0       Jamaica, NY     NaN    4782.0    26877.0   117561.0
# 245  11436.0       Jamaica, NY     NaN     545.0     1966.0     8487.0
# 246  11451.0       Jamaica, NY       B       0.0        0.0        0.0
# 247  11691.0  Far Rockaway, NY     NaN    8882.0    57059.0   232035.0
# 248  11692.0  Far Rockaway, NY     NaN    1373.0     8513.0    41164.0
# 249  11693.0  Far Rockaway, NY     NaN     860.0     4529.0    20037.0
# 250  11693.0  Far Rockaway, NY     NaN     860.0     4529.0    20037.0
# 251  11693.0  Far Rockaway, NY     NaN     860.0     4529.0    20037.0
# 252  11693.0  Far Rockaway, NY     NaN     860.0     4529.0    20037.0
# 253  11694.0  Far Rockaway, NY     NaN    2185.0     9873.0    43612.0
# 254  11697.0  Far Rockaway, NY     NaN     240.0     1158.0     6221.0
# 255      NaN               NaN     NaN       NaN        NaN        NaN
#
#         est  ZIPCODE BLDGZIP              PO_NAME  \
# 0    6999.0  10001.0       0             New York
# 1    1784.0  10002.0       0             New York
# 2    3256.0  10003.0       0             New York
# 3    1115.0  10004.0       0             New York
# 4    1115.0  10004.0       0             New York
# 5    1115.0  10004.0       0             New York
# 6    1115.0  10004.0       0             New York
# 7    1076.0  10005.0       0             New York
# 8    1061.0  10006.0       0             New York
# 9    1307.0  10007.0       0             New York
# 10    634.0  10009.0       0             New York
# 11   3019.0  10010.0       0             New York
# 12   3301.0  10011.0       0             New York
# 13   2385.0  10012.0       0             New York
# 14   5318.0  10013.0       0             New York
# 15   1733.0  10014.0       0             New York
# 16   5718.0  10016.0       0             New York
# 17   5684.0  10017.0       0             New York
# 18   6059.0  10018.0       0             New York
# 19   4750.0  10019.0       0             New York
# 20    651.0  10020.0       0             New York
# 21   5092.0  10021.0       0             New York
# 22   6433.0  10022.0       0             New York
# 23   2021.0  10023.0       0             New York
# 24   1696.0  10024.0       0             New York
# 25   1566.0  10025.0       0             New York
# 26    134.0  10026.0       0             New York
# 27    683.0  10027.0       0             New York
# 28   1772.0  10028.0       0             New York
# 29    637.0  10029.0       0             New York
# ..      ...      ...     ...                  ...
# 226   433.0  11414.0       0         Howard Beach
# 227   314.0  11415.0       0          Kew Gardens
# 228   334.0  11416.0       0           Ozone Park
# 229   371.0  11417.0       0           Ozone Park
# 230   576.0  11418.0       0        Richmond Hill
# 231   405.0  11419.0       0  South Richmond Hill
# 232   225.0  11420.0       0     South Ozone Park
# 233   330.0  11421.0       0            Woodhaven
# 234   267.0  11422.0       0             Rosedale
# 235   263.0  11423.0       0               Hollis
# 236   326.0  11426.0       0            Bellerose
# 237   170.0  11427.0       0       Queens Village
# 238   197.0  11428.0       0       Queens Village
# 239   160.0  11429.0       0       Queens Village
# 240   274.0  11430.0       0              Jamaica
# 241  1002.0  11432.0       0              Jamaica
# 242   226.0  11433.0       0              Jamaica
# 243   760.0  11434.0       0              Jamaica
# 244   586.0  11435.0       0              Jamaica
# 245    51.0  11436.0       0              Jamaica
# 246     2.0  11451.0       0              Jamaica
# 247   401.0  11691.0       0         Far Rockaway
# 248    66.0  11692.0       0              Arverne
# 249    95.0  11693.0       0         Far Rockaway
# 250    95.0  11693.0       0         Far Rockaway
# 251    95.0  11693.0       0         Far Rockaway
# 252    95.0  11693.0       0         Far Rockaway
# 253   294.0  11694.0       0        Rockaway Park
# 254    33.0  11697.0       0         Breezy Point
# 255     NaN      NaN     NaN                  NaN
#
#                            ...                          POPULATION  \
# 0                          ...                             22413.0
# 1                          ...                             81305.0
# 2                          ...                             55878.0
# 3                          ...                              2187.0
# 4                          ...                              2187.0
# 5                          ...                              2187.0
# 6                          ...                              2187.0
# 7                          ...                              8107.0
# 8                          ...                              3011.0
# 9                          ...                              7323.0
# 10                         ...                             61455.0
# 11                         ...                             29881.0
# 12                         ...                             50594.0
# 13                         ...                             24276.0
# 14                         ...                             27985.0
# 15                         ...                             31328.0
# 16                         ...                             54606.0
# 17                         ...                             15918.0
# 18                         ...                              5503.0
# 19                         ...                             41966.0
# 20                         ...                                 0.0
# 21                         ...                             45299.0
# 22                         ...                             33135.0
# 23                         ...                             62800.0
# 24                         ...                             58521.0
# 25                         ...                             96054.0
# 26                         ...                             34313.0
# 27                         ...                             58639.0
# 28                         ...                             47530.0
# 29                         ...                             77503.0
# ..                         ...                                 ...
# 226                        ...                             36607.0
# 227                        ...                             47054.0
# 228                        ...                             44538.0
# 229                        ...                             39014.0
# 230                        ...                             30139.0
# 231                        ...                             30243.0
# 232                        ...                             20050.0
# 233                        ...                             21942.0
# 234                        ...                             18818.0
# 235                        ...                             25116.0
# 236                        ...                                16.0
# 237                        ...                             62075.0
# 238                        ...                             33679.0
# 239                        ...                             57989.0
# 240                        ...                             53404.0
# 241                        ...                             18681.0
# 242                        ...                                 0.0
# 243                        ...                             60267.0
# 244                        ...                             18018.0
# 245                        ...                             11052.0
# 246                        ...                             11052.0
# 247                        ...                             11052.0
# 248                        ...                             11052.0
# 249                        ...                             20163.0
# 250                        ...                              4079.0
# 251                        ...                                 NaN
# 252                        ...                                 NaN
# 253                        ...                                 NaN
# 254                        ...                                 NaN
# 255                        ...                                 NaN
#
#              AREA STATE    COUNTY ST_FIPS CTY_FIPS                   URL  \
# 0    1.779494e+07    NY  New York      36      061  http://www.usps.com/
# 1    2.628013e+07    NY  New York      36      061  http://www.usps.com/
# 2    1.553838e+07    NY  New York      36      061  http://www.usps.com/
# 3    4.002521e+06    NY  New York      36      061  http://www.usps.com/
# 4    1.202708e+06    NY  New York      36      061  http://www.usps.com/
# 5    7.679616e+06    NY  New York      36      061  http://www.usps.com/
# 6    6.707080e+05    NY  New York      36      061  http://www.usps.com/
# 7    2.082901e+06    NY  New York      36      061  http://www.usps.com/
# 8    1.716641e+06    NY  New York      36      061  http://www.usps.com/
# 9    5.327871e+06    NY  New York      36      061  http://www.usps.com/
# 10   1.590352e+07    NY  New York      36      061  http://www.usps.com/
# 11   9.768396e+06    NY  New York      36      061  http://www.usps.com/
# 12   1.811842e+07    NY  New York      36      061  http://www.usps.com/
# 13   9.193739e+06    NY  New York      36      061  http://www.usps.com/
# 14   1.558058e+07    NY  New York      36      061  http://www.usps.com/
# 15   1.415105e+07    NY  New York      36      061  http://www.usps.com/
# 16   1.504240e+07    NY  New York      36      061  http://www.usps.com/
# 17   9.794383e+06    NY  New York      36      061  http://www.usps.com/
# 18   1.070580e+07    NY  New York      36      061  http://www.usps.com/
# 19   1.882838e+07    NY  New York      36      061  http://www.usps.com/
# 20   6.972970e+05    NY  New York      36      061  http://www.usps.com/
# 21   1.049513e+07    NY  New York      36      061  http://www.usps.com/
# 22   1.272834e+07    NY  New York      36      061  http://www.usps.com/
# 23   1.521271e+07    NY  New York      36      061  http://www.usps.com/
# 24   2.287734e+07    NY  New York      36      061  http://www.usps.com/
# 25   1.963104e+07    NY  New York      36      061  http://www.usps.com/
# 26   1.109268e+07    NY  New York      36      061  http://www.usps.com/
# 27   2.469528e+07    NY  New York      36      061  http://www.usps.com/
# 28   9.842046e+06    NY  New York      36      061  http://www.usps.com/
# 29   2.296344e+07    NY  New York      36      061  http://www.usps.com/
# ..            ...   ...       ...     ...      ...                   ...
# 226  3.202513e+07    NY    Queens      36      081  http://www.usps.com/
# 227  3.127886e+07    NY    Queens      36      081  http://www.usps.com/
# 228  6.187957e+07    NY    Queens      36      081  http://www.usps.com/
# 229  2.431444e+07    NY    Queens      36      081  http://www.usps.com/
# 230  6.012066e+07    NY    Queens      36      081  http://www.usps.com/
# 231  4.509503e+07    NY    Queens      36      081  http://www.usps.com/
# 232  4.960916e+07    NY    Queens      36      081  http://www.usps.com/
# 233  3.943577e+07    NY    Queens      36      081  http://www.usps.com/
# 234  2.192755e+07    NY    Queens      36      081  http://www.usps.com/
# 235  3.955940e+07    NY    Queens      36      081  http://www.usps.com/
# 236  1.999137e+08    NY    Queens      36      081  http://www.usps.com/
# 237  6.017758e+07    NY    Queens      36      081  http://www.usps.com/
# 238  4.773943e+07    NY    Queens      36      081  http://www.usps.com/
# 239  8.737970e+07    NY    Queens      36      081  http://www.usps.com/
# 240  4.210590e+07    NY    Queens      36      081  http://www.usps.com/
# 241  2.269930e+07    NY    Queens      36      081  http://www.usps.com/
# 242  4.875997e+05    NY    Queens      36      081  http://www.usps.com/
# 243  8.392782e+07    NY    Queens      36      081  http://www.usps.com/
# 244  2.399240e+07    NY    Queens      36      081  http://www.usps.com/
# 245  4.647173e+07    NY    Queens      36      081  http://www.usps.com/
# 246  1.527599e+06    NY    Queens      36      081  http://www.usps.com/
# 247  1.227092e+07    NY    Queens      36      081  http://www.usps.com/
# 248  3.497516e+06    NY     Kings      36      047  http://www.usps.com/
# 249  4.810161e+07    NY    Queens      36      081  http://www.usps.com/
# 250  5.978976e+07    NY    Queens      36      081  http://www.usps.com/
# 251           NaN   NaN       NaN     NaN      NaN                   NaN
# 252           NaN   NaN       NaN     NaN      NaN                   NaN
# 253           NaN   NaN       NaN     NaN      NaN                   NaN
# 254           NaN   NaN       NaN     NaN      NaN                   NaN
# 255           NaN   NaN       NaN     NaN      NaN                   NaN
#
#      SHAPE_AREA  SHAPE_LEN                                           geometry
# 0           0.0        0.0  POLYGON ((981958.6472873986 213464.4530421346,...
# 1           0.0        0.0  POLYGON ((991339.8703228086 207576.7837151289,...
# 2           0.0        0.0  POLYGON ((989830.469142139 207048.1263078749, ...
# 3           0.0        0.0  POLYGON ((981197.408652395 196571.0816452205, ...
# 4           0.0        0.0  POLYGON ((972696.8446168154 193014.5477478057,...
# 5           0.0        0.0  POLYGON ((977542.4500830621 188447.2783390433,...
# 6           0.0        0.0  POLYGON ((971218.3702115566 190710.8587856293,...
# 7           0.0        0.0  POLYGON ((982595.6794779003 195880.7536295503,...
# 8           0.0        0.0  POLYGON ((981136.3431577235 198082.3837407082,...
# 9           0.0        0.0  POLYGON ((980538.9073447287 200658.5114624649,...
# 10          0.0        0.0  POLYGON ((991606.4032543153 205494.1464762092,...
# 11          0.0        0.0  POLYGON ((987500.0003778934 210146.4376965463,...
# 12          0.0        0.0  POLYGON ((986378.4337233901 210178.5990495533,...
# 13          0.0        0.0  POLYGON ((985200.0558308065 205072.0203519613,...
# 14          0.0        0.0  POLYGON ((983216.1014653891 203868.9381124675,...
# 15          0.0        0.0  POLYGON ((983985.4854253083 205856.7261316329,...
# 16          0.0        0.0  POLYGON ((989286.3432618976 213322.780097127, ...
# 17          0.0        0.0  POLYGON ((990440.5063079 215404.9508015513, 99...
# 18          0.0        0.0  POLYGON ((983778.6019808054 216668.1490625441,...
# 19          0.0        0.0  POLYGON ((986161.7127001435 220802.6076571345,...
# 20          0.0        0.0  POLYGON ((990566.3797438145 215633.2423397154,...
# 21          0.0        0.0  POLYGON ((998204.3503602296 218909.3384778053,...
# 22          0.0        0.0  POLYGON ((991852.9732992351 217950.6957100481,...
# 23          0.0        0.0  POLYGON ((986170.3206225634 221389.1589774638,...
# 24          0.0        0.0  POLYGON ((994210.0381388962 234868.6605617106,...
# 25          0.0        0.0  POLYGON ((995501.6553063095 232971.115144223, ...
# 26          0.0        0.0  POLYGON ((999588.2622905672 231919.4308958799,...
# 27          0.0        0.0  POLYGON ((998641.2454838157 236978.8715643883,...
# 28          0.0        0.0  POLYGON ((995349.451214388 224260.552840963, 9...
# 29          0.0        0.0  POLYGON ((999072.8305786401 230985.3760054708,...
# ..          ...        ...                                                ...
# 226         0.0        0.0  POLYGON ((1029400.592101485 197246.1842976362,...
# 227         0.0        0.0  POLYGON ((1029301.697942317 191200.7022941262,...
# 228         0.0        0.0  POLYGON ((1037510.873124972 189653.9419362098,...
# 229         0.0        0.0  POLYGON ((1026065.502643064 193710.0053463876,...
# 230         0.0        0.0  POLYGON ((1060642.852451473 188482.9035958797,...
# 231         0.0        0.0  POLYGON ((1047964.521508977 205966.9598350525,...
# 232         0.0        0.0  POLYGON ((1063134.367809638 208633.765525043, ...
# 233         0.0        0.0  POLYGON ((1058755.729585305 206326.356097877, ...
# 234         0.0        0.0  POLYGON ((1058328.643497229 205085.9658621252,...
# 235         0.0        0.0  POLYGON ((1059514.14276664 201987.3906944692, ...
# 236         0.0        0.0  POLYGON ((1042671.560966313 182294.7224027216,...
# 237         0.0        0.0  POLYGON ((1037183.602782145 201617.3205684721,...
# 238         0.0        0.0  POLYGON ((1045331.84468773 197513.7421614677, ...
# 239         0.0        0.0  POLYGON ((1048057.740154564 193045.403329134, ...
# 240         0.0        0.0  POLYGON ((1032469.175859317 199963.2661338001,...
# 241         0.0        0.0  POLYGON ((1038098.251871482 188138.3800067157,...
# 242         0.0        0.0  POLYGON ((1039268.607142314 194809.8673198819,...
# 243         0.0        0.0  POLYGON ((1054519.887991399 162245.7592198849,...
# 244         0.0        0.0  POLYGON ((1041797.849787235 157921.3987741321,...
# 245         0.0        0.0  POLYGON ((1030865.641008645 170727.6658124626,...
# 246         0.0        0.0  POLYGON ((1030722.649496734 160980.7696238756,...
# 247         0.0        0.0  POLYGON ((1036087.150250643 154632.6386193782,...
# 248         0.0        0.0  POLYGON ((1028453.99491331 167153.4098376334, ...
# 249         0.0        0.0  POLYGON ((1034425.419650227 153503.8255883008,...
# 250         0.0        0.0  POLYGON ((1016691.779920727 146366.408760801, ...
# 251         NaN        NaN                                                NaN
# 252         NaN        NaN                                                NaN
# 253         NaN        NaN                                                NaN
# 254         NaN        NaN                                                NaN
# 255         NaN        NaN                                                NaN
#
# [256 rows x 459 columns]

# %%
appended_data.shape
# Out:
# (256, 459)

# %% [raw]
# AP              N       Total Annual Payroll ($1,000) with Noise
# AP_NF           C       Total Annual Payroll Noise Flag
# EMP_NF          C       Total Mid-March Employees Noise Flag (See all Noise Flag definitions at the end of this record layout)
# EMP             N       Total Mid-March Employees with Noise
# EST             N       Total Number of Establishments
# QP1_NF          C       Total First Quarter Payroll Noise Flag
# QP1             N       Total First Quarter Payroll ($1,000) with Noise

# %%
df1 = appended_data[['est','zip']]
df1.columns = ['94', '95', '96','97', '98','99', '00','01', '02', '03','04','05', '06', '07', '08','09', '10', '11', '12', '13', '14', 'zip', 'zip0' 'zip1', 'zip2', 'zip3', 'zip4', 'zip5', 'zip6', 'zip7', 'zip8', 'zip9', 'zip10', 'zip11', 'zip12', 'zip13', 'zip14', 'zip15', 'zip16', 'zip17', 'zip18', 'zip19', 'zip20']
df2 = df1[['94', '95', '96','97', '98','99', '00','01', '02', '03','04','05', '06', '07', '08','09', '10', '11', '12', '13', '14', 'zip']]
df2.head()
# Out:
#        94      95      96      97      98      99      00      01      02  \
# 0  6999.0  7088.0  7075.0  7154.0  7254.0  7233.0  7317.0  7188.0  7141.0
# 1  1784.0  1819.0  1919.0  2049.0  2003.0  2085.0  2277.0  2543.0  2269.0
# 2  3256.0  3377.0  3417.0  3535.0  3649.0  3659.0  3683.0  3602.0  3616.0
# 3  1115.0  1124.0  1133.0  1173.0  1176.0  1233.0  1294.0  1247.0  1253.0
# 4  1115.0  1124.0  1133.0  1173.0  1176.0  1233.0  1294.0  1247.0  1253.0
#
#        03   ...         06    07      08      09      10      11      12  \
# 0  7084.0   ...     7415.0  7549  7472.0  7305.0  7241.0  7227.0  7235.0
# 1  2402.0   ...     2686.0  2685  2691.0  2775.0  2872.0  2912.0  2954.0
# 2  3704.0   ...     3909.0  4049  4071.0  4099.0  4113.0  4159.0  4214.0
# 3  1252.0   ...     1311.0  1370  1376.0  1379.0  1398.0  1404.0  1442.0
# 4  1252.0   ...     1311.0  1370  1376.0  1379.0  1398.0  1404.0  1442.0
#
#        13      14      zip
# 0  7273.0  7369.0  10001.0
# 1  2988.0  2972.0  10002.0
# 2  4277.0  4333.0  10003.0
# 3  1479.0  1554.0  10004.0
# 4  1479.0  1554.0  10004.0
#
# [5 rows x 22 columns]

# %%
df2.dropna(axis=0, inplace=True)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.shape
# Out:
# (249, 22)

# %% [markdown]
# After merging and cleaning for nan values, I have 249 zipcodes and 21 timestamps per time series

# %% [markdown]
# ## Whitening
# * Whitenings decorrelates the data: it makes the features independent so that the data covariance matrix is the identity matrix. Whitening your data in time series analysis is in most cases wrong: you are modifying your time behaviour. This is because of the strong correlation between features (two consecutive time stamps for the same observation, the same zip code here, are strongly correlated).
#
# * Here instead you want to standardize your time series: subtract the mean and divide each time series (separately) by its standard deviation.
#
# * As a sanity check (if you use skitlearn Kmeans or skitlearns kmeans2): you want your data array to be shaped Nzipcodes x Ntimestamps
#     - mydata.shape should be (Nzipcodes, Ntimestamps)
#     - mydata[i].std() shoould be 1 for all i in range(len(Nzipcodes))
#     - mydata[i].mean() should be ~0 for all i in range(len(Nzipcodes))

# %%
df2.head()
# Out:
#        94      95      96      97      98      99      00      01      02  \
# 0  6999.0  7088.0  7075.0  7154.0  7254.0  7233.0  7317.0  7188.0  7141.0
# 1  1784.0  1819.0  1919.0  2049.0  2003.0  2085.0  2277.0  2543.0  2269.0
# 2  3256.0  3377.0  3417.0  3535.0  3649.0  3659.0  3683.0  3602.0  3616.0
# 3  1115.0  1124.0  1133.0  1173.0  1176.0  1233.0  1294.0  1247.0  1253.0
# 4  1115.0  1124.0  1133.0  1173.0  1176.0  1233.0  1294.0  1247.0  1253.0
#
#        03   ...         06    07      08      09      10      11      12  \
# 0  7084.0   ...     7415.0  7549  7472.0  7305.0  7241.0  7227.0  7235.0
# 1  2402.0   ...     2686.0  2685  2691.0  2775.0  2872.0  2912.0  2954.0
# 2  3704.0   ...     3909.0  4049  4071.0  4099.0  4113.0  4159.0  4214.0
# 3  1252.0   ...     1311.0  1370  1376.0  1379.0  1398.0  1404.0  1442.0
# 4  1252.0   ...     1311.0  1370  1376.0  1379.0  1398.0  1404.0  1442.0
#
#        13      14      zip
# 0  7273.0  7369.0  10001.0
# 1  2988.0  2972.0  10002.0
# 2  4277.0  4333.0  10003.0
# 3  1479.0  1554.0  10004.0
# 4  1479.0  1554.0  10004.0
#
# [5 rows x 22 columns]

# %%
mydata = df2.as_matrix(columns=df2.columns[:-1])
d = len(mydata[0])
n = len(mydata)
print ("number of features: ", d)
print ("number of data points: ", n)
# Out:
# ('number of features: ', 21)
# ('number of data points: ', 249)

# %%
mydata.shape
# Out:
# (249, 21)

# %%
df2_mean = df2.iloc[:,range(0,21)].mean(axis=1)
df2_std = df2.iloc[:,range(0,21)].std(axis=1)
df2.iloc[:,range(0,21)] = df2.iloc[:,range(0,21)].apply(lambda x: (x- df2_mean) / df2_std)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df2.head()
# Out:
#          94        95        96        97        98        99        00  \
# 0 -1.839191 -1.193297 -1.287641 -0.714319  0.011404 -0.140998  0.468610
# 1 -1.713540 -1.626405 -1.377447 -1.053802 -1.168323 -0.964178 -0.486179
# 2 -1.820497 -1.434653 -1.307101 -0.930824 -0.567301 -0.535414 -0.458882
# 3 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
# 4 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
#
#          01        02        03   ...           06        07        08  \
# 0 -0.467573 -0.808663 -1.222326   ...     1.179819  2.152288  1.593481
# 1  0.176049 -0.506095 -0.174982   ...     0.532058  0.529569  0.544506
# 2 -0.717175 -0.672532 -0.391918   ...     0.261785  0.708216  0.778369
# 3 -0.420990 -0.371369 -0.379639   ...     0.108300  0.596238  0.645859
# 4 -0.420990 -0.371369 -0.379639   ...     0.108300  0.596238  0.645859
#
#          09        10        11        12        13        14      zip
# 0  0.381523 -0.082940 -0.184541 -0.126483  0.149292  0.845986  10001.0
# 1  0.753631  0.995120  1.094703  1.199265  1.283911  1.244077  10002.0
# 2  0.867655  0.912298  1.058983  1.234367  1.435260  1.613833  10003.0
# 3  0.670669  0.827802  0.877423  1.191688  1.497684  2.117945  10004.0
# 4  0.670669  0.827802  0.877423  1.191688  1.497684  2.117945  10004.0
#
# [5 rows x 22 columns]

# %%
#merge back to shapefile 
df3 = df2.merge(dfzip, left_on='zip', right_on='ZIPCODE')
df3.head()
# Out:
#          94        95        96        97        98        99        00  \
# 0 -1.839191 -1.193297 -1.287641 -0.714319  0.011404 -0.140998  0.468610
# 1 -1.713540 -1.626405 -1.377447 -1.053802 -1.168323 -0.964178 -0.486179
# 2 -1.820497 -1.434653 -1.307101 -0.930824 -0.567301 -0.535414 -0.458882
# 3 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
# 4 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
#
#          01        02        03  \
# 0 -0.467573 -0.808663 -1.222326
# 1  0.176049 -0.506095 -0.174982
# 2 -0.717175 -0.672532 -0.391918
# 3 -0.420990 -0.371369 -0.379639
# 4 -0.420990 -0.371369 -0.379639
#
#                          ...                          POPULATION  \
# 0                        ...                             22413.0
# 1                        ...                             81305.0
# 2                        ...                             55878.0
# 3                        ...                              2187.0
# 4                        ...                              2187.0
#
#            AREA  STATE    COUNTY  ST_FIPS  CTY_FIPS                   URL  \
# 0  1.779494e+07     NY  New York       36       061  http://www.usps.com/
# 1  2.628013e+07     NY  New York       36       061  http://www.usps.com/
# 2  1.553838e+07     NY  New York       36       061  http://www.usps.com/
# 3  4.002521e+06     NY  New York       36       061  http://www.usps.com/
# 4  1.202708e+06     NY  New York       36       061  http://www.usps.com/
#
#    SHAPE_AREA  SHAPE_LEN                                           geometry
# 0         0.0        0.0  POLYGON ((981958.6472873986 213464.4530421346,...
# 1         0.0        0.0  POLYGON ((991339.8703228086 207576.7837151289,...
# 2         0.0        0.0  POLYGON ((989830.469142139 207048.1263078749, ...
# 3         0.0        0.0  POLYGON ((981197.408652395 196571.0816452205, ...
# 4         0.0        0.0  POLYGON ((972696.8446168154 193014.5477478057,...
#
# [5 rows x 35 columns]

# %% [markdown]
# cluster the NUMBER OF ESTABLISHMENTS time series with K-means in **a few** clusters (as discussed there is no real good, sound way to decide what a good number is here. try a few options, keeping in mind a few is more than a couple, but i recommand you stay within the single digit numbers)

# %%
#apply clustering
n=5
rr = KMeans(n_clusters=n, init='k-means++', n_init=10, max_iter=500, tol=0.0001, 
                verbose=0, random_state=None).fit(df3.iloc[:,range(1,21)])

# %%
#set centers
centers = rr.cluster_centers_

# %%
pl.figure(figsize=(12,12))
pl.scatter(df3[rr.labels_ == 0].iloc[:,0], df3[rr.labels_ == 0].iloc[:,20], \
           c='b', alpha=0.5, label="Cluster 1")
pl.scatter(centers[0][0], centers[0][-1], marker='*', s=120, c='b', label="Cluster 1 Center")

pl.scatter(df3[rr.labels_ == 1].iloc[:,0], df3[rr.labels_ == 1].iloc[:,20], \
           c='g', alpha=0.5, label="Cluster 2")
pl.scatter(centers[1][0], centers[1][-1], marker='*', s=120, c='g', label="Cluster 2 Center")

pl.scatter(df3[rr.labels_ == 2].iloc[:,0], df3[rr.labels_ == 2].iloc[:,20], \
           c='r', alpha=0.5, label="Cluster 3")
pl.scatter(centers[2][0], centers[2][-1], marker='*', s=120, c='r', label="Cluster 3 Center")

pl.scatter(df3[rr.labels_ == 3].iloc[:,0], df3[rr.labels_ == 3].iloc[:,20], \
           c='m', alpha=0.5, label="Cluster 4")
pl.scatter(centers[3][0], centers[3][-1], marker='*', s=120, c='m', label="Cluster 4 Center")

pl.scatter(df3[rr.labels_ == 4].iloc[:,0], df3[rr.labels_ == 4].iloc[:,20], \
            c='y', alpha=0.5, label="Cluster 5")
pl.scatter(centers[4][0], centers[4][-1], marker='*', s=120, c='y', label="Cluster 5 Center")

pl.xlabel("EST94")
pl.ylabel("EST14")
pl.title("KMeans Cluster: Number of Establishments in Zip Code")
pl.legend(fontsize=10, loc='best')

# %% [markdown]
# Figure 1: Kmeans cluster of number of establishments by zipcode

# %% [markdown]
# ### Perform the Hierarchical Clustering
# As the scipy linkage docs tell us, 'ward' is one of the methods that can be used to calculate the distance between newly formed clusters. 'ward' causes linkage() to use the Ward variance minimization algorithm.
#
# * other common linkage methods like 'single', 'complete', 'average', ... and the different distance metrics like 'euclidean' (default), 'cityblock' aka Manhattan, 'hamming', 'cosine'...
#
# code from: https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/

# %%
# generate the linkage matrix
X= df3.iloc[:,range(0,20)]
Z = linkage(X, 'ward')

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

c, coph_dists = cophenet(Z, pdist(X))
c
# Out:
# 0.54854063962682709

# %% [markdown]
# Another thing you can and should definitely do is check the Cophenetic Correlation Coefficient of your clustering with help of the cophenet() function. This (very very briefly) compares (correlates) the actual pairwise distances of all your samples to those implied by the hierarchical clustering. The closer the value is to 1, the better the clustering preserves the original distances, which in this case is not very close

# %%
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram', fontsize=20)
plt.xlabel('sample index', fontsize=20)
plt.ylabel('distance', fontsize=20)
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %% [markdown]
# Figure 2: Hierarchical Clustering Dendrogram of Number of Establishments by zip code

# %%
k=5
den_label = fcluster(Z, k, criterion='maxclust')

# %% [markdown]
# overlay your data on a NYC map: you can use shapefiles for the zip codes and different colors for different clusters

# %%
df3['kmeans'] = rr.labels_
df3['Dendrogram'] = den_label

# %%
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(df3, crs=crs, geometry='geometry')

# %%
gdf.head()
# Out:
#          94        95        96        97        98        99        00  \
# 0 -1.839191 -1.193297 -1.287641 -0.714319  0.011404 -0.140998  0.468610
# 1 -1.713540 -1.626405 -1.377447 -1.053802 -1.168323 -0.964178 -0.486179
# 2 -1.820497 -1.434653 -1.307101 -0.930824 -0.567301 -0.535414 -0.458882
# 3 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
# 4 -1.512649 -1.438217 -1.363786 -1.032980 -1.008170 -0.536772 -0.032293
#
#          01        02        03     ...      STATE    COUNTY  ST_FIPS  \
# 0 -0.467573 -0.808663 -1.222326     ...         NY  New York       36
# 1  0.176049 -0.506095 -0.174982     ...         NY  New York       36
# 2 -0.717175 -0.672532 -0.391918     ...         NY  New York       36
# 3 -0.420990 -0.371369 -0.379639     ...         NY  New York       36
# 4 -0.420990 -0.371369 -0.379639     ...         NY  New York       36
#
#    CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0       061  http://www.usps.com/         0.0        0.0
# 1       061  http://www.usps.com/         0.0        0.0
# 2       061  http://www.usps.com/         0.0        0.0
# 3       061  http://www.usps.com/         0.0        0.0
# 4       061  http://www.usps.com/         0.0        0.0
#
#                                             geometry  kmeans  Dendrogram
# 0  POLYGON ((981958.6472873986 213464.4530421346,...       3           4
# 1  POLYGON ((991339.8703228086 207576.7837151289,...       1           4
# 2  POLYGON ((989830.469142139 207048.1263078749, ...       1           4
# 3  POLYGON ((981197.408652395 196571.0816452205, ...       1           4
# 4  POLYGON ((972696.8446168154 193014.5477478057,...       1           4
#
# [5 rows x 37 columns]

# %%
# plot timeseries clusters
fig = plt.figure(figsize = (15,30))
ax = fig.add_subplot(211)
ax1 = fig.add_subplot(212)
gdf.plot(ax=ax, colormap='Blues', column='kmeans', categorical=True, edgecolor='k', k=4, legend=True)
ax.set_title("KMeans, k=5", fontsize=15)
gdf.plot(ax=ax1, colormap='Blues', column='Dendrogram', categorical=True, edgecolor='k', k=4, legend=True)
ax1.set_title("Hierarchical Clustering, k=5", fontsize=15)
ax.grid(False)

# %% [markdown]
# Figure 3: Geographical represenation of kmeans clustering and hierarchical clustering of business establishments by zipcode (n=5)

# %% [markdown]
# Each color represent one cluster. Figure 3 reveals a spatial clustering of the number of establishments. However, there is a slight difference in the way the clustering methods cluster the data. Hierarchical clustering may have grouped more zipcodes togeher as it calculates the distance between clusters.

# %%
cluster.iloc[:,:-15].head()
# Out:
#           94        95        96        97        98        99        00  \
# 21 -0.444220 -0.717132 -0.882533 -0.609621 -0.650971 -0.477300 -0.278819
# 57  0.526977  0.182191  0.159947  0.093214  0.204435  0.182191  0.315657
# 69  0.936740  1.325725  1.307202  1.696187 -1.137848 -0.322831 -1.137848
# 78  1.033460  1.173308  1.308785  1.391820 -1.103592 -1.029298 -1.081741
# 92  1.224102  1.234066  1.293848  1.567847 -0.992804 -0.723786 -0.997786
#
#           01        02        03   ...           06        07        08  \
# 21 -1.056204  2.144307  2.003716   ...    -0.568271 -0.634431 -0.394600
# 57  0.271168 -0.006885  0.093214   ...    -0.418404 -0.540748 -0.540748
# 69 -1.119325 -1.119325 -1.137848   ...    -0.600678 -0.619201  0.899694
# 78 -1.086111 -1.103592 -1.112332   ...    -0.601013 -0.653456  1.160197
# 92 -1.002767 -0.977858 -0.962913   ...    -0.444805 -0.399968  1.089593
#
#           09        10        11        12        13        14      zip
# 21 -0.692322 -0.254009  0.060253  0.324895  0.523376  0.746668  10007.0
# 57 -0.596358 -0.674213 -0.663091 -0.663091 -0.707580 -0.729824  10043.0
# 69  0.751509  0.695939 -0.193169 -0.119077 -0.267262 -0.193169  10103.0
# 78  0.981017  0.841169 -0.050362 -0.085324 -0.094064 -0.085324  10118.0
# 92  1.044757  0.895303 -0.539459 -0.579313 -0.534477 -0.554404  10165.0
#
# [5 rows x 22 columns]

# %%
fig = pl.figure(figsize=(15,10))
n=5
for k in range(n):
    ax = fig.add_subplot(3,2,k+1)
    cluster = gdf[gdf['kmeans'] == k]
    ax.plot(cluster.iloc[:,:-16], c='k', alpha=0.1)
    ax.plot(cluster.iloc[:,:-16].mean(), c='r')
    ax.set_xticklabels(cluster.columns[:-16])
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.set_xlabel('year', fontsize=15)
    ax.set_ylabel('Standardized Business Counts', fontsize=10)
    ax.set_xlim([1994,2014])
    ax.set_title("Agglomerative Clustering k = {}".format(str(k)))
    
pl.tight_layout()

# %%
pl.plot(cluster.iloc[:,:-16], c='k', alpha=0.1)
# Out:
# [<matplotlib.lines.Line2D at 0x7f4785446110>,
#  <matplotlib.lines.Line2D at 0x7f4785446550>,
#  <matplotlib.lines.Line2D at 0x7f4785446210>,
#  <matplotlib.lines.Line2D at 0x7f4785446a90>,
#  <matplotlib.lines.Line2D at 0x7f47854467d0>,
#  <matplotlib.lines.Line2D at 0x7f4785446810>,
#  <matplotlib.lines.Line2D at 0x7f47854469d0>,
#  <matplotlib.lines.Line2D at 0x7f4786a495d0>,
#  <matplotlib.lines.Line2D at 0x7f4786a49cd0>,
#  <matplotlib.lines.Line2D at 0x7f4786a49890>,
#  <matplotlib.lines.Line2D at 0x7f4786927a10>,
#  <matplotlib.lines.Line2D at 0x7f4786415150>,
#  <matplotlib.lines.Line2D at 0x7f4786415810>,
#  <matplotlib.lines.Line2D at 0x7f4786415610>,
#  <matplotlib.lines.Line2D at 0x7f4786415cd0>,
#  <matplotlib.lines.Line2D at 0x7f4786415f50>,
#  <matplotlib.lines.Line2D at 0x7f4785f7ea50>,
#  <matplotlib.lines.Line2D at 0x7f47854beed0>,
#  <matplotlib.lines.Line2D at 0x7f4787a08c50>,
#  <matplotlib.lines.Line2D at 0x7f4786714090>,
#  <matplotlib.lines.Line2D at 0x7f4786ad8c50>]
